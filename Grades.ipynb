# %%
# Importing all the necessary libraries here.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.simplefilter("ignore")
import joblib

# %%
df=pd.read_csv('D:\My Documents\Internship\dataset4-main/grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
# encoding

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()

# %%
df2=lab_enc.fit_transform(df['Seat No.'])
df['Seat No.']=df2

# %%
df2=lab_enc.fit_transform(df['PH-121'])
df['PH-121']=df2

# %%
df2=lab_enc.fit_transform(df['HS-101'])
df['HS-101']=df2

# %%
df2=lab_enc.fit_transform(df['CY-105'])
df['CY-105']=df2

# %%
df2=lab_enc.fit_transform(df['HS-105/12'])
df['HS-105/12']=df2

# %%
df2=lab_enc.fit_transform(df['MT-111'])
df['MT-111']=df2

# %%
df2=lab_enc.fit_transform(df['CS-105'])
df['CS-105']=df2

# %%
df2=lab_enc.fit_transform(df['CS-106'])
df['CS-106']=df2

# %%
df2=lab_enc.fit_transform(df['EL-102'])
df['EL-102']=df2

# %%
df2=lab_enc.fit_transform(df['EE-119'])
df['EE-119']=df2

# %%
df2=lab_enc.fit_transform(df['ME-107'])
df['ME-107']=df2

# %%
df2=lab_enc.fit_transform(df['CS-107'])
df['CS-107']=df2

# %%
df2=lab_enc.fit_transform(df['HS-205/20'])
df['HS-205/20']=df2

# %%
df2=lab_enc.fit_transform(df['MT-222'])
df['MT-222']=df2

# %%
df2=lab_enc.fit_transform(df['EE-222'])
df['EE-222']=df2

# %%
df2=lab_enc.fit_transform(df['MT-224'])
df['MT-224']=df2

# %%
df2=lab_enc.fit_transform(df['CS-210'])
df['CS-210']=df2

# %%
df2=lab_enc.fit_transform(df['CS-211'])
df['CS-211']=df2

# %%
df2=lab_enc.fit_transform(df['CS-203'])
df['CS-203']=df2

# %%
df2=lab_enc.fit_transform(df['CS-214'])
df['CS-214']=df2

# %%
df2=lab_enc.fit_transform(df['EE-217'])
df['EE-217']=df2

# %%
df2=lab_enc.fit_transform(df['CS-212'])
df['CS-212']=df2

# %%
df2=lab_enc.fit_transform(df['CS-215'])
df['CS-215']=df2

# %%
df2=lab_enc.fit_transform(df['MT-331'])
df['MT-331']=df2

# %%
df2=lab_enc.fit_transform(df['EF-303'])
df['EF-303']=df2

# %%
df2=lab_enc.fit_transform(df['HS-304'])
df['HS-304']=df2

# %%
df2=lab_enc.fit_transform(df['CS-301'])
df['CS-301']=df2

# %%
df2=lab_enc.fit_transform(df['CS-302'])
df['CS-302']=df2

# %%
df2=lab_enc.fit_transform(df['TC-383'])
df['TC-383']=df2

# %%
df2=lab_enc.fit_transform(df['MT-442'])
df['MT-442']=df2

# %%
df2=lab_enc.fit_transform(df['EL-332'])
df['EL-332']=df2

# %%
df2=lab_enc.fit_transform(df['CS-318'])
df['CS-318']=df2

# %%
df2=lab_enc.fit_transform(df['CS-306'])
df['CS-306']=df2

# %%
df2=lab_enc.fit_transform(df['CS-312'])
df['CS-312']=df2

# %%
df2=lab_enc.fit_transform(df['CS-317'])
df['CS-317']=df2

# %%
df2=lab_enc.fit_transform(df['CS-403'])
df['CS-403']=df2

# %%
df2=lab_enc.fit_transform(df['CS-421'])
df['CS-421']=df2

# %%
df2=lab_enc.fit_transform(df['CS-406'])
df['CS-406']=df2

# %%
df2=lab_enc.fit_transform(df['CS-414'])
df['CS-414']=df2

# %%
df2=lab_enc.fit_transform(df['CS-419'])
df['CS-419']=df2

# %%
df2=lab_enc.fit_transform(df['CS-423'])
df['CS-423']=df2

# %%
df2=lab_enc.fit_transform(df['CS-412'])
df['CS-412']=df2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    int32
#  1   PH-121     571 non-null    int32
#  2   HS-101     571 non-null    int32
#  3   CY-105     571 non-null    int32
#  4   HS-105/12  571 non-null    int32
#  5   MT-111     571 non-null    int32
#  6   CS-105     571 non-null    int32
#  7   CS-106     571 non-null    int32
#  8   EL-102     571 non-null    int32
#  9   EE-119     571 non-null    int32
#  10  ME-107     571 non-null    int32
#  11  CS-107     571 non-null    int32
#  12  HS-205/20  571 non-null    int32
#  13  MT-222     571 non-null    int32
#  14  EE-222     571 non-null    int32
#  15  MT-224     571 non-null    int32
#  16  CS-210     571 non-null    int32
#  17  CS-211     571 non-null    int32
#  18  CS-203     571 non-null    int32
#  19  CS-214     571 non-null    int32
# ...

# %%
df.describe()
# Out:
#          Seat No.      PH-121      HS-101      CY-105   HS-105/12      MT-111  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean   285.000000    3.781086    5.071804    2.921191    4.264448    3.935201
# std    164.977776    3.046895    2.785317    2.992228    3.216478    3.034481
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    142.500000    2.000000    3.000000    0.000000    2.000000    2.000000
# 50%    285.000000    3.000000    5.000000    2.000000    4.000000    4.000000
# 75%    427.500000    6.000000    7.000000    5.000000    7.000000    6.000000
# max    570.000000   12.000000   11.000000   13.000000   13.000000   13.000000
#
#            CS-105      CS-106      EL-102      EE-119  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.838879    4.161121    3.998249    3.921191  ...    4.299475
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# # Distribution

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=45:
        plt.subplot(15,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
# almost all are normally distributed

# %% [markdown]
# # relationship - feature v/s label

# %%
df.drop('CGPA',axis=1).corrwith(df.CGPA)
# Out:
# Seat No.     0.054342
# PH-121      -0.663135
# HS-101      -0.537170
# CY-105      -0.670190
# HS-105/12   -0.627644
# MT-111      -0.756109
# CS-105      -0.613169
# CS-106      -0.563178
# EL-102      -0.669536
# EE-119      -0.668787
# ME-107      -0.677342
# CS-107      -0.650531
# HS-205/20   -0.500668
# MT-222      -0.695418
# EE-222      -0.644384
# MT-224      -0.743577
# CS-210      -0.798841
# CS-211      -0.669814
# CS-203      -0.682817
# CS-214      -0.758407
# EE-217      -0.703131
# CS-212      -0.686163
# CS-215      -0.768707
# MT-331      -0.610787
# EF-303      -0.589066
# HS-304      -0.656729
# CS-301      -0.747775
# CS-302      -0.770868
# TC-383      -0.682447
# MT-442      -0.656557
# EL-332      -0.803475
# CS-318      -0.660106
# CS-306      -0.783624
# CS-312      -0.562341
# CS-317      -0.800771
# CS-403      -0.657128
# CS-421      -0.742041
# CS-406      -0.280626
# CS-414      -0.512836
# CS-419      -0.732899
# CS-423      -0.624558
# ...

# %%
# Feature v/s feature

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
x=df.drop(columns=['CGPA'])
y=df['CGPA']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['Columns']=x.columns
print(vif)
# Out:
#          vif    Columns
# 0   3.953174   Seat No.
# 1   3.118867     PH-121
# 2   1.802595     HS-101
# 3   2.751345     CY-105
# 4   2.417495  HS-105/12
# 5   2.735090     MT-111
# 6   2.463383     CS-105
# 7   2.068960     CS-106
# 8   2.195081     EL-102
# 9   2.180870     EE-119
# 10  2.454950     ME-107
# 11  2.557454     CS-107
# 12  1.905364  HS-205/20
# 13  2.494664     MT-222
# 14  2.752321     EE-222
# 15  3.175359     MT-224
# 16  3.915989     CS-210
# 17  2.853153     CS-211
# 18  2.821677     CS-203
# 19  2.977456     CS-214
# 20  2.836508     EE-217
# 21  3.131039     CS-212
# 22  3.329627     CS-215
# 23  2.301369     MT-331
# 24  2.496434     EF-303
# 25  3.133744     HS-304
# 26  3.491515     CS-301
# 27  3.175722     CS-302
# 28  3.318012     TC-383
# 29  2.302946     MT-442
# 30  3.734270     EL-332
# 31  2.834537     CS-318
# 32  4.049506     CS-306
# 33  3.760500     CS-312
# 34  3.581160     CS-317
# 35  3.024198     CS-403
# 36  3.221129     CS-421
# ...

# %%
# No multicollinearity found. We can take all.

# %% [markdown]
# # Train-test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=42)

# %%
# As it is a regression problem, we will use linear regression for modelling purpose.

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_test,y_test)
# Out:
# 0.9028210517217902

# %%
# We can't use hyper-parameter tuning on LinearRegression as parameters are specific here.

# %%
filename = "FinalModel.pkl"
joblib.dump(lm, filename)
# Out:
# ['FinalModel.pkl']
